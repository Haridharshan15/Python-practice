# %% [markdown]
# <a href="https://colab.research.google.com/github/Haridharshan15/Python-practice/blob/main/SimpleFlightBooking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class kk():
    def __init__(self,name,age,From,to,seat):
        self.h1=name
        self.h2=age
        self.h3=From
        self.h4=to
        self.h5=seat # self.h5 now represents the initial total number of seats

        # Corrected: Initialize a list 'seats_status' to represent each seat's availability.
        # Assuming '1' means available and 'Booked' means taken.
        seats_status = ['1'] * self.h5

        booked_a_seat = False
        # Iterate through the indices of the seats_status list
        for i in range(len(seats_status)):
            # Original condition `if seats[i]!="1":` was inverted if '1' means available.
            if seats_status[i] == "1": # Check if the current seat is available
                print(f"Your ticket got booked at seat no {i+1}") # Assuming seat numbers start from 1
                self.h5 = self.h5 - 1 # Decrement the count of remaining available seats
                seats_status[i] = "Booked" # Mark this specific seat as booked
                booked_a_seat = True
                break # Book one seat and exit the loop

        if not booked_a_seat and seat > 0: # If no seat was booked, but there were initial seats
            print("No available seats to book.")

"""name=input("Enter your NAME and AGE : ")
name=input("Enter your AGE : ")
From=input("From : ")
to=input("To : ")"""
name='Hari';age=20;From='Chennai';to='Bangalore'
seat=4
if seat==0 :
    print("Seats Unavailable")

else :
    print("'Please wait for your confirmation'")
    call=kk(name,age,From,to,seat)
# Out:
# 'Please wait for your confirmation'
# Your ticket got booked at seat no 1
